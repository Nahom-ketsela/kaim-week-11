# %%
# Import modules
import sys
import os
import pandas as pd

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Append the project root path to sys.path
sys.path.append(os.path.abspath("../scripts"))

# %%
# Import Custom Module
import Time_series_forcasting_models as tsfm

# %%
# Fetch and preprocess data
train, test = tsfm.fetch_and_preprocess_data('TSLA', '2015-01-01', '2025-01-31')
# Out:
# YF.download() has changed argument auto_adjust default to True
# *********************100%***********************]  1 of 1 completed

# %%
# Display the first few rows of training data
train.head()
# Out:
# Ticker           TSLA
# Date
# 2015-01-02  14.620667
# 2015-01-05  14.006000
# 2015-01-06  14.085333
# 2015-01-07  14.063333
# 2015-01-08  14.041333

# %%
from statsmodels.tsa.stattools import adfuller

# Perform Augmented Dickey-Fuller test
result = adfuller(train)

# Extract the p-value
print('ADF Statistic:', result[0])
print('p-value:', result[1])

# Interpretation:
if result[1] <= 0.05:
    print("The series is likely stationary (reject the null hypothesis)")
else:
    print("The series is likely non-stationary (fail to reject the null hypothesis)")
# Out:
# ADF Statistic: -1.3071175481635393
# p-value: 0.6259097682416385
# The series is likely non-stationary (fail to reject the null hypothesis)

# %%
import matplotlib.pyplot as plt

# Plotting the time series data
plt.plot(train)
plt.title('Time Series Data - Visual Inspection')
plt.show()

# %%
# Train ARIMA model
arima_forecast, arima_model = tsfm.train_arima_model(train, test)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=12684.802, Time=0.81 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12680.726, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12679.653, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12679.753, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12678.997, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=12680.805, Time=0.72 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.094 seconds
# C:\Users\HP\OneDrive\Desktop\ai2\kaim-week-11\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Evaluate ARIMA model
tsfm.evaluate_model(test, arima_forecast, 'ARIMA')
# Out:
# ARIMA Model Evaluation:
# MAE: 89.9096
# RMSE: 111.0784
# MAPE: 34.61%

# %%
# Train SARIMA model
sarima_forecast, conf_sarima, sarima_model = tsfm.train_sarima_model(train, test)

# %%
# Evaluate SARIMA model
tsfm.evaluate_model(test, sarima_forecast, 'SARIMA')
# Out:
# SARIMA Model Evaluation:
# MAE: 130.1167
# RMSE: 151.6919
# MAPE: 49.62%

# %%
# Train LSTM model
lstm_forecast, lstm_model, data_scaler = tsfm.train_lstm_model(train, test, n_steps=60, epochs=20, batch_size=32)
# Out:
# C:\Users\HP\OneDrive\Desktop\ai2\kaim-week-11\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - loss: 0.0256
# Epoch 2/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0021
# Epoch 3/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0021
# Epoch 4/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0019
# Epoch 5/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.0021
# Epoch 6/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0017
# Epoch 7/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.0015
# Epoch 8/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0012
# Epoch 9/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0015
# Epoch 10/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0013
# Epoch 11/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0010
# Epoch 12/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0012
# Epoch 13/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0013
# Epoch 14/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.0012
# Epoch 15/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 9.8219e-04
# Epoch 16/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0010
# Epoch 17/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0010
# Epoch 18/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - loss: 0.0011
# Epoch 19/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0010
# Epoch 20/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0011
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step

# %%
# Plot the results
plt.figure(figsize=(15, 8))
plt.plot(test.index, test.values, color='blue', label='Real Stock Price')  # Real data
plt.plot(test.index, lstm_forecast, color='red', label='Predicted Stock Price')  # Predicted data
plt.title('Stock Price Prediction using LSTM')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Ensure ltsm_forecast is a 1D array 
ltsm_forecast = np.array(lstm_forecast).ravel()  # Convert (507, 1) to (507,)

# Ensure test is also 1D
test = np.array(test).ravel()

# calculate MAE, RMSE, and MAPE 
mae = mean_absolute_error(test, lstm_forecast)
rmse = np.sqrt(mean_squared_error(test, lstm_forecast))
mape = np.mean(np.abs((test - lstm_forecast) / test)) * 100

print(f'LSTM Model Evaluation:')
print(f'MAE: {mae:.4f}')
print(f'RMSE: {rmse:.4f}')
print(f'MAPE: {mape:.2f}%')
# Out:
# LSTM Model Evaluation:
# MAE: 10.7805
# RMSE: 14.5138
# MAPE: 27.32%

# %%
# task3_forecast_analysis.py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def forecast_lstm_future(
    model, 
    data_series,    # Pandas Series with a DatetimeIndex, ends ~2025
    scaler, 
    n_steps=60, 
    n_periods=126   # ~6 months if freq='B'
):
    """
    Forecast the next 'n_periods' time steps using an already-trained LSTM model.
    
    Parameters
    ----------
    model : Trained LSTM model (Keras).
    data_series : pd.Series
        The *full* historical data up to the end of 2025 (or your final date). 
        Must have a DatetimeIndex.
    scaler : e.g., MinMaxScaler or StandardScaler used in training.
    n_steps : int
        The window size the LSTM model expects (e.g., 60 days).
    n_periods : int
        Number of future steps to forecast (126 ~ 6 mo; 252 ~ 12 mo, if daily freq).

    Returns
    -------
    future_forecast : np.ndarray of shape (n_periods,)
    future_dates : pd.DatetimeIndex
    """

    # 1) Ensure data is sorted by date
    data_series = data_series.sort_index()

    # 2) Convert to numpy and scale
    full_data_arr = data_series.values.reshape(-1, 1)
    full_data_scaled = scaler.transform(full_data_arr)

    # 3) Extract the final 'n_steps' from the dataset as the model input
    if len(full_data_scaled) < n_steps:
        raise ValueError("Not enough data to form a window of size n_steps.")
    last_window = full_data_scaled[-n_steps:]  # shape (n_steps, 1)

    # 4) Iteratively predict n_periods steps ahead
    future_scaled_preds = []
    
    X_input = last_window.copy()  # shape (n_steps, 1)

    for _ in range(n_periods):
        # Reshape for LSTM: (1 batch, n_steps timesteps, 1 feature)
        X_input_reshaped = X_input.reshape(1, n_steps, 1)

        # Predict the next step
        pred_scaled = model.predict(X_input_reshaped)
        # pred_scaled is shape (1,1), take pred_scaled[0,0] => float
        next_val = pred_scaled[0, 0]

        # Append to future predictions
        future_scaled_preds.append(next_val)

        # Shift the window: drop the oldest, append the new prediction
        X_input = np.append(X_input[1:], [[next_val]], axis=0)

    # 5) Inverse-transform the forecast to original scale
    future_forecast = scaler.inverse_transform(
        np.array(future_scaled_preds).reshape(-1, 1)
    ).flatten()

    # 6) Create a future date range 
    last_date = data_series.index[-1]
    future_dates = pd.date_range(
        start=last_date, 
        periods=n_periods + 1, 
        freq='B'
    )[1:]  # skip the last known date => start from the day after

    # 7) Plot the historical + forecast
    plt.figure(figsize=(10, 6))
    plt.plot(data_series.index, data_series, label='Historical (2015–2025)', color='blue')
    plt.plot(future_dates, future_forecast, label='Forecast (Next 6–12 Mo)', color='orange')
    plt.title('LSTM Forecast')
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()

    return future_forecast, future_dates
   

def interpret_results(future_forecast, future_dates):
    """
    Interpret the forecasted results to identify trends, volatility, and risks.
    
    Parameters:
        future_forecast (np.array): Forecasted values (length N).
        future_dates (pd.DatetimeIndex): Dates for the forecasted values (length N).
    """

    # Safety check
    if len(future_forecast) == 0 or len(future_dates) == 0:
        print("No forecast data to interpret.")
        return
    if len(future_forecast) != len(future_dates):
        print("Warning: future_forecast and future_dates are misaligned in length.")
    
    # 1) Determine upward or downward trend based on first vs. last forecast
    first_val = future_forecast[0]
    last_val = future_forecast[-1]
    trend = 'upward' if last_val > first_val else 'downward'
    
    # 2) Calculate approximate date range in days/months
    start_date = future_dates[0]
    end_date   = future_dates[-1]
    delta_days = (end_date - start_date).days
    approx_months = round(delta_days / 30.44)  # ~30.44 days per month on average
    
    # 3) Percentage change from first to last forecast
    pct_change = (last_val - first_val) / first_val * 100 if first_val != 0 else 0
    
    # 4) Measure volatility via standard deviation
    volatility_abs = np.std(future_forecast)
    mean_forecast  = np.mean(future_forecast)
    volatility_rel = (volatility_abs / mean_forecast * 100) if mean_forecast != 0 else 0

    # 5) Print interpretation
    # Trend
    print(f"Forecast Period: {start_date.date()} to {end_date.date()} (~{approx_months} months)")
    print(f"Trend: The forecast suggests a {trend} movement over this period.")
    print(f"Price change: from {first_val:.2f} to {last_val:.2f} ({pct_change:+.2f}%).")

    # Volatility
    print(f"Volatility (std): {volatility_abs:.2f}")
    print(f"Relative Volatility: {volatility_rel:.2f}% of average forecast value.\n")
    
    # Market opportunity/risk commentary
    if trend == 'upward':
        print("Potential Market Opportunity: The expected price increase may present buying opportunities.")
    else:
        print("Potential Market Risk: The expected price decline suggests caution in investment (or shorting opportunities).")
    
    # Additional risk commentary if volatility is high
    # (Threshold is arbitrary; adjust to taste)
    if volatility_rel > 10:
        print("Note: Volatility appears relatively high (std > 10% of mean). "
              "This implies greater uncertainty in the forecast.")
    else:
        print("Volatility appears moderate, implying relatively stable expectations under the model.")

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit_transform(train.values.reshape(-1,1))
# Out:
# array([[0.01259433],
#        [0.01105916],
#        [0.0112573 ],
#        ...,
#        [0.29369218],
#        [0.30930188],
#        [0.3351016 ]])

# %%
future_values_6mo, future_dates_6mo = forecast_lstm_future(
    model=lstm_model,
    data_series=train,
    scaler=scaler,
    n_steps=60,       # or whatever window you used for LSTM
    n_periods=126
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
# Interpret results
interpret_results(future_forecast, future_dates)
# Out:
# The forecast suggests a downward trend in Tesla stock prices over the next 12 months.
# The forecasted volatility is 0.17, indicating the level of uncertainty in the predictions.
# Potential Market Risk: Expected price decline may suggest caution in investment.
