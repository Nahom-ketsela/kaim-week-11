# %%
# Import modules
import sys
import os
import pandas as pd

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Append the project root path to sys.path
sys.path.append(os.path.abspath("../scripts"))

# %%
# Import Custom Module
import Time_series_forcasting_models as tsfm

# %%
# Fetch and preprocess data
train, test = tsfm.fetch_and_preprocess_data('TSLA', '2015-01-01', '2025-01-31')
# Out:
# YF.download() has changed argument auto_adjust default to True
# *********************100%***********************]  1 of 1 completed

# %%
# Train LSTM model
lstm_forecast, lstm_model, data_scaler = tsfm.train_lstm_model(train, test, n_steps=60, epochs=20, batch_size=32)
# Out:
# C:\Users\HP\OneDrive\Desktop\ai2\kaim-week-11\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 31s 95ms/step - loss: 0.0330
# Epoch 2/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 0.0021
# Epoch 3/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0019
# Epoch 4/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 0.0020
# Epoch 5/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 0.0016
# Epoch 6/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - loss: 0.0015
# Epoch 7/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - loss: 0.0014
# Epoch 8/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0018
# Epoch 9/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0014
# Epoch 10/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0016
# Epoch 11/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0012
# Epoch 12/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0012
# Epoch 13/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.0010
# Epoch 14/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0013
# Epoch 15/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0011
# Epoch 16/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 9.8623e-04
# Epoch 17/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0013
# Epoch 18/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0010
# Epoch 19/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0014
# Epoch 20/20
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0012
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step

# %%
# scaler for forecasting
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit_transform(train.values.reshape(-1,1))
# Out:
# array([[0.01259433],
#        [0.01105916],
#        [0.0112573 ],
#        ...,
#        [0.29369218],
#        [0.30930188],
#        [0.3351016 ]])

# %%
# forcast values for the next 6 month 
future_values_6mo, future_dates_6mo = tsfm.forecast_lstm_future(
    model=lstm_model,
    data_series=train,
    scaler=scaler,
    n_steps=60,      
    n_periods=126
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
import yfinance as yf
import pandas as pd

# Fetch BND data from Yahoo Finance
bnd_df = yf.download("BND", start="2015-01-01", end="2025-1-31")

# Extract the 'Close' column as a Series
bnd_series = bnd_df['Close'].sort_index()

# To ensure consistent daily frequency
bnd_series = bnd_series.asfreq('B').ffill()
# Out:
# *********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import pandas as pd

# Fetch SPY data from Yahoo Finance
spy_df = yf.download("SPY", start="2015-01-01", end="2025-1-31")

# Extract the 'Close' column as a Series
spy_series = spy_df['Close'].sort_index()

# To ensure consistent daily frequency
spy_series = spy_series.asfreq('B').ffill()
# Out:
# *********************100%***********************]  1 of 1 completed

# %%
# Extract the 'Close' column as a Series
bnd_series = bnd_df['Close'].sort_index()

bnd_series = bnd_series.asfreq('B').ffill()

# %%
# Extract the 'Close' column as a Series
spy_series = spy_df['Close'].sort_index()

spy_series = spy_series.asfreq('B').ffill()

# %%
# Import Custom Module
import portofolio_optimization as po

# %%
# BND loading
future_bnd = pd.Series(po.naive_forecast(bnd_series, forecast_horizon=126), name='BND')

# Print sample output
print(future_bnd)
# Out:
# 0      71.987063
# 1      71.984129
# 2      71.981195
# 3      71.978261
# 4      71.975327
#          ...
# 121    71.632886
# 122    71.629966
# 123    71.627047
# 124    71.624127
# 125    71.621208
# Name: BND, Length: 126, dtype: float64

# %%
# SPY loading
future_spy = pd.Series(po.naive_forecast(spy_series, forecast_horizon=126), name='SPY')

# Print sample output
print(future_spy)
# Out:
# 0      605.209221
# 1      605.378512
# 2      605.547850
# 3      605.717236
# 4      605.886669
#           ...
# 121    626.041042
# 122    626.216160
# 123    626.391327
# 124    626.566543
# 125    626.741807
# Name: SPY, Length: 126, dtype: float64

# %%
# merge the 3 forcasted values into a single dataframe.
import pandas as pd

# Convert NumPy array to Pandas Series
future_values_6mo_series = pd.Series(future_values_6mo, index=future_bnd.index, name="TSLA")

# Concatenate the three Series
df_forecast = pd.concat([future_values_6mo_series, future_bnd, future_spy], axis=1)

# Drop NaN values 
df_forecast.dropna(inplace=True)
df_forecast.sort_index(inplace=True)

print("Combined forecast data:")
print(df_forecast.head())
# Out:
# Combined forecast data:
#          TSLA        BND         SPY
# 0  142.472580  71.987063  605.209221
# 1  145.822937  71.984129  605.378512
# 2  149.296844  71.981195  605.547850
# 3  152.863220  71.978261  605.717236
# 4  156.502686  71.975327  605.886669

# %%
# Optimize the portfolio
weights, stats = po.optimize_portfolio(df_forecast, rf=0.0)
print("\nOptimal Weights:", dict(zip(df_forecast.columns, weights)))
print(f"Expected Annual Return: {stats['return']:.2%}")
print(f"Expected Volatility: {stats['volatility']:.2%}")
print(f"Sharpe Ratio: {stats['sharpe']:.2f}")
# Out:
# Optimal Weights: {'TSLA': 1.1657341758564144e-15, 'BND': 0.0, 'SPY': 0.9999999999999989}
# Expected Annual Return: 7.05%
# Expected Volatility: 0.00%
# Sharpe Ratio: 465934186167647.06

# %%
# Compute portfolio daily returns for VaR
daily_returns = df_forecast.pct_change().dropna()
port_daily = (daily_returns * weights).sum(axis=1)
var_95 = po.compute_var(port_daily, confidence=0.95)
print(f"\nPortfolio 95% Daily VaR: {var_95:.2%}")
# Out:
# Portfolio 95% Daily VaR: -0.03%

# %%
# distribution of portofolio daily return
port_daily = (df_forecast.pct_change().dropna() * weights).sum(axis=1)
po.plot_var_distribution(port_daily, confidence=0.95)

# %%
# We need annualized returns & cov from forecast data:

daily_returns = df_forecast.pct_change().dropna()
annual_returns = daily_returns.mean() * 252
annual_cov = daily_returns.cov() * 252

# %%
# Evaluate performance
port_return, port_vol, port_sharpe = po.portfolio_performance(
    weights, annual_returns, annual_cov, rf=0.0
)
print("Return:", port_return, "Vol:", port_vol, "Sharpe:", port_sharpe)
# Out:
# Return: 0.07049011744517006 Vol: 1.5128771302436073e-16 Sharpe: 465934186167647.06

# %%
# plot forecastd data
po.plot_asset_forecasts(df_forecast)

# %%
# porotofolio cumulatuve return
daily_returns = df_forecast.pct_change().dropna()
port_daily = (daily_returns * weights).sum(axis=1)
po.plot_portfolio_cumulative(port_daily)
