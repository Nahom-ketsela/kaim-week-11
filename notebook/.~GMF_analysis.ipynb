# %%
# Import modules
import sys
import os
import pandas as pd

# %%
# Append the project root path to sys.path
sys.path.append(os.path.abspath("../scripts"))

# %%
# Import Custom Module
import GMF_preprocessing as gp

# %% [markdown]
# -----------------------------------------------TSLA Dataset--------------------------------------------------------------------

# %%
#define the fetching data values
# assets = ["TSLA", "BND", "SPY"]
start_date = "2015-01-01"
end_date = "2025-01-31"
    
# Fetch and preprocess data for TSLA
df_TSLA = gp.fetch_data("TSLA", start_date, end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# *********************100%***********************]  1 of 1 completed

# %%
#check the fetched data
print(df_TSLA.columns)
df_TSLA.head()
# Out:
# Index(['Close TSLA', 'High TSLA', 'Low TSLA', 'Open TSLA', 'Volume TSLA'], dtype='object')
#             Close TSLA  High TSLA   Low TSLA  Open TSLA  Volume TSLA
# Date
# 2015-01-02   14.620667  14.883333  14.217333  14.858000     71466000
# 2015-01-05   14.006000  14.433333  13.810667  14.303333     80527500
# 2015-01-06   14.085333  14.280000  13.614000  14.004000     93928500
# 2015-01-07   14.063333  14.318667  13.985333  14.223333     44526000
# 2015-01-08   14.041333  14.253333  14.000667  14.187333     51637500

# %%
#check missing value
gp.check_missing_values(df_TSLA)
# Out:
# Missing values per asset:
# Close TSLA     0
# High TSLA      0
# Low TSLA       0
# Open TSLA      0
# Volume TSLA    0
# dtype: int64
# Close TSLA     0
# High TSLA      0
# Low TSLA       0
# Open TSLA      0
# Volume TSLA    0
# dtype: int64

# %%
#preprocessing df
gp.preprocess_data(df_TSLA)
# Out:
# C:\Users\HP\OneDrive\Desktop\ai2\kaim-week-11\scripts\GMF_preprocessing.py:28: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# (            Close TSLA   High TSLA    Low TSLA   Open TSLA  Volume TSLA
#  Date
#  2015-01-02   14.620667   14.883333   14.217333   14.858000     71466000
#  2015-01-05   14.006000   14.433333   13.810667   14.303333     80527500
#  2015-01-06   14.085333   14.280000   13.614000   14.004000     93928500
#  2015-01-07   14.063333   14.318667   13.985333   14.223333     44526000
#  2015-01-08   14.041333   14.253333   14.000667   14.187333     51637500
#  ...                ...         ...         ...         ...          ...
#  2025-01-24  406.579987  418.880005  405.779999  414.450012     56427100
#  2025-01-27  397.149994  406.690002  389.000000  394.799988     58125500
# ...

# %%
# EDA for TSLA
gp.plot_stock_data(df_TSLA)

# %%
gp.plot_histogram(df_TSLA)

# %%
gp.plot_closing_price(df_TSLA)

# %%
gp.plot_daily_returns(df_TSLA)
# Out:
#             Close TSLA  High TSLA  Low TSLA  Open TSLA
# Date
# 2015-01-05   -0.042041  -0.030235 -0.028604  -0.037331
# 2015-01-06    0.005664  -0.010624 -0.014240  -0.020928
# 2015-01-07   -0.001562   0.002708  0.027276   0.015662
# 2015-01-08   -0.001564  -0.004563  0.001096  -0.002531
# 2015-01-09   -0.018802  -0.017867 -0.024047  -0.018279
# ...                ...        ...       ...        ...
# 2025-01-24   -0.014065  -0.004397 -0.007752  -0.003870
# 2025-01-27   -0.023193  -0.029101 -0.041352  -0.047412
# 2025-01-28    0.002367  -0.014999 -0.006427   0.005345
# 2025-01-29   -0.022583  -0.004993 -0.005226  -0.004283
# 2025-01-30    0.028733   0.034898 -0.000182   0.039397
#
# [2534 rows x 4 columns]

# %%
gp.plot_volatility(df_TSLA)

# %%
gp.detect_outliers(df_TSLA)
# Out:
#             Close TSLA  High TSLA  Low TSLA  Open TSLA
# Date
# 2015-01-05         NaN        NaN       NaN        NaN
# 2015-01-06         NaN        NaN       NaN        NaN
# 2015-01-07         NaN        NaN       NaN        NaN
# 2015-01-08         NaN        NaN       NaN        NaN
# 2015-01-09         NaN        NaN       NaN        NaN
# ...                ...        ...       ...        ...
# 2025-01-24         NaN        NaN       NaN        NaN
# 2025-01-27         NaN        NaN       NaN        NaN
# 2025-01-28         NaN        NaN       NaN        NaN
# 2025-01-29         NaN        NaN       NaN        NaN
# 2025-01-30         NaN        NaN       NaN        NaN
#
# [2534 rows x 4 columns]

# %%
gp.analyze_volume_outliers(df_TSLA)
# Out:
#             Volume TSLA
# Date
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08          NaN
# ...                 ...
# 2025-01-24          NaN
# 2025-01-27          NaN
# 2025-01-28          NaN
# 2025-01-29          NaN
# 2025-01-30          NaN
#
# [2535 rows x 1 columns]

# %%
gp.plot_rolling_mean(df_TSLA)

# %%
gp.decompose_time_series(df_TSLA, 'Close TSLA')

# %% [markdown]
# -----------------------------------------------BND Dataset--------------------------------------------------------------------

# %%
#define the fetching data values

start_date = "2015-01-01"
end_date = "2025-01-31"
    
# Fetch and preprocess data for BND
df_BND = gp.fetch_data("BND", start_date, end_date)
# Out:
# *********************100%***********************]  1 of 1 completed

# %%
#check the fetched data
print(df_BND.columns)
df_BND.head()
# Out:
# Index(['Close BND', 'High BND', 'Low BND', 'Open BND', 'Volume BND'], dtype='object')
#             Close BND   High BND    Low BND   Open BND  Volume BND
# Date
# 2015-01-02  62.573109  62.603393  62.398976  62.406549     2218800
# 2015-01-05  62.754795  62.777507  62.610947  62.641231     5820100
# 2015-01-06  62.936523  63.125795  62.860816  62.860816     3887600
# 2015-01-07  62.974377  63.050084  62.875958  62.944093     2433400
# 2015-01-08  62.875992  62.921415  62.815424  62.921415     1873400

# %%
#check missing value
gp.check_missing_values(df_BND)
# Out:
# Missing values per asset:
# Close BND     0
# High BND      0
# Low BND       0
# Open BND      0
# Volume BND    0
# dtype: int64
# Close BND     0
# High BND      0
# Low BND       0
# Open BND      0
# Volume BND    0
# dtype: int64

# %%
#preprocessing df
gp.preprocess_data(df_BND)
# Out:
# C:\Users\HP\OneDrive\Desktop\ai2\kaim-week-11\scripts\GMF_preprocessing.py:28: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# (            Close BND   High BND    Low BND   Open BND  Volume BND
#  Date
#  2015-01-02  62.573109  62.603393  62.398976  62.406549     2218800
#  2015-01-05  62.754795  62.777507  62.610947  62.641231     5820100
#  2015-01-06  62.936523  63.125795  62.860816  62.860816     3887600
#  2015-01-07  62.974377  63.050084  62.875958  62.944093     2433400
#  2015-01-08  62.875992  62.921415  62.815424  62.921415     1873400
#  ...               ...        ...        ...        ...         ...
#  2025-01-24  71.805977  71.855810  71.636531  71.766106     5555700
#  2025-01-27  72.184738  72.204677  72.025262  72.104996     8621200
#  2025-01-28  72.144867  72.154837  71.975421  72.154837     4424300
# ...

# %%
# EDA for BND
gp.plot_stock_data(df_BND)

# %%
gp.plot_histogram(df_BND)

# %%
gp.plot_closing_price(df_BND)

# %%
gp.plot_daily_returns(df_BND)
# Out:
#             Close BND  High BND   Low BND      Open BND
# Date
# 2015-01-05   0.002904  0.002781  0.003397  3.760538e-03
# 2015-01-06   0.002896  0.005548  0.003991  3.505437e-03
# 2015-01-07   0.000601 -0.001199  0.000241  1.324776e-03
# 2015-01-08  -0.001562 -0.002041 -0.000963 -3.602790e-04
# 2015-01-09   0.001686  0.002166  0.000362 -1.203149e-03
# ...               ...       ...       ...           ...
# 2025-01-24   0.001947  0.001250  0.000975  6.499320e-08
# 2025-01-27   0.005275  0.004855  0.005426  4.722150e-03
# 2025-01-28  -0.000552 -0.000690 -0.000692  6.912194e-04
# 2025-01-29  -0.000553  0.001381 -0.000554  5.525718e-04
# 2025-01-30   0.001382  0.000552  0.002910  4.141320e-04
#
# [2534 rows x 4 columns]

# %%
gp.plot_volatility(df_BND)

# %%
gp.detect_outliers(df_BND)
# Out:
#             Close BND  High BND  Low BND  Open BND
# Date
# 2015-01-05        NaN       NaN      NaN       NaN
# 2015-01-06        NaN       NaN      NaN       NaN
# 2015-01-07        NaN       NaN      NaN       NaN
# 2015-01-08        NaN       NaN      NaN       NaN
# 2015-01-09        NaN       NaN      NaN       NaN
# ...               ...       ...      ...       ...
# 2025-01-24        NaN       NaN      NaN       NaN
# 2025-01-27        NaN       NaN      NaN       NaN
# 2025-01-28        NaN       NaN      NaN       NaN
# 2025-01-29        NaN       NaN      NaN       NaN
# 2025-01-30        NaN       NaN      NaN       NaN
#
# [2534 rows x 4 columns]

# %%
gp.analyze_volume_outliers(df_BND)
# Out:
#             Volume BND
# Date
# 2015-01-02         NaN
# 2015-01-05         NaN
# 2015-01-06         NaN
# 2015-01-07         NaN
# 2015-01-08         NaN
# ...                ...
# 2025-01-24         NaN
# 2025-01-27         NaN
# 2025-01-28         NaN
# 2025-01-29         NaN
# 2025-01-30         NaN
#
# [2535 rows x 1 columns]

# %%
gp.plot_rolling_mean(df_BND)

# %%
gp.decompose_time_series(df_BND, 'Close BND')

# %% [markdown]
# -----------------------------------------------SPY Dataset--------------------------------------------------------------------

# %%
#define the fetching data values
start_date = "2015-01-01"
end_date = "2025-01-31"
    
# Fetch and preprocess data for SPY
df_SPY= gp.fetch_data("SPY", start_date, end_date)
# Out:
# *********************100%***********************]  1 of 1 completed

# %%
#check the fetched data
print(df_SPY.columns)
df_SPY.head()
# Out:
# Index(['Close SPY', 'High SPY', 'Low SPY', 'Open SPY', 'Volume SPY'], dtype='object')
#              Close SPY    High SPY     Low SPY    Open SPY  Volume SPY
# Date
# 2015-01-02  172.592880  173.811114  171.542687  173.391037   121465900
# 2015-01-05  169.475876  171.702279  169.165023  171.534251   169632600
# 2015-01-06  167.879578  170.316019  167.073024  169.786718   209151400
# 2015-01-07  169.971603  170.316070  168.770189  169.223867   125346700
# 2015-01-08  172.987778  173.206226  171.383093  171.399886   147217800

# %%
#check missing value
gp.check_missing_values(df_SPY)
# Out:
# Missing values per asset:
# Close SPY     0
# High SPY      0
# Low SPY       0
# Open SPY      0
# Volume SPY    0
# dtype: int64
# Close SPY     0
# High SPY      0
# Low SPY       0
# Open SPY      0
# Volume SPY    0
# dtype: int64

# %%
#preprocessing df
gp.preprocess_data(df_SPY)
# Out:
# C:\Users\HP\OneDrive\Desktop\ai2\kaim-week-11\scripts\GMF_preprocessing.py:28: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# (             Close SPY    High SPY     Low SPY    Open SPY  Volume SPY
#  Date
#  2015-01-02  172.592880  173.811114  171.542687  173.391037   121465900
#  2015-01-05  169.475876  171.702279  169.165023  171.534251   169632600
#  2015-01-06  167.879578  170.316019  167.073024  169.786718   209151400
#  2015-01-07  169.971603  170.316070  168.770189  169.223867   125346700
#  2015-01-08  172.987778  173.206226  171.383093  171.399886   147217800
#  ...                ...         ...         ...         ...         ...
#  2025-01-24  607.969971  610.780029  606.799988  609.809998    34604700
#  2025-01-27  599.369995  599.690002  594.640015  594.809998    70361100
# ...

# %%
# EDA for TSLA
gp.plot_stock_data(df_SPY)

# %%
gp.plot_histogram(df_SPY)

# %%
gp.plot_closing_price(df_SPY)

# %%
gp.plot_daily_returns(df_SPY)
# Out:
#             Close SPY      High SPY   Low SPY  Open SPY
# Date
# 2015-01-05  -0.018060 -1.213291e-02 -0.013860 -0.010709
# 2015-01-06  -0.009419 -8.073625e-03 -0.012367 -0.010188
# 2015-01-07   0.012461  2.971756e-07  0.010158 -0.003315
# 2015-01-08   0.017745  1.696937e-02  0.015482  0.012859
# 2015-01-09  -0.008013  1.261419e-03 -0.002353  0.011715
# ...               ...           ...       ...       ...
# 2025-01-24  -0.002919  1.689265e-03  0.002114  0.006619
# 2025-01-27  -0.014145 -1.815715e-02 -0.020040 -0.024598
# 2025-01-28   0.008592  9.471548e-03  0.004389  0.009768
# 2025-01-29  -0.004483 -2.048318e-03  0.003298  0.005161
# 2025-01-30   0.005367  4.088475e-03  0.002503  0.000398
#
# [2534 rows x 4 columns]

# %%
gp.plot_volatility(df_SPY)

# %%
gp.detect_outliers(df_SPY)
# Out:
#             Close SPY  High SPY  Low SPY  Open SPY
# Date
# 2015-01-05        NaN       NaN      NaN       NaN
# 2015-01-06        NaN       NaN      NaN       NaN
# 2015-01-07        NaN       NaN      NaN       NaN
# 2015-01-08        NaN       NaN      NaN       NaN
# 2015-01-09        NaN       NaN      NaN       NaN
# ...               ...       ...      ...       ...
# 2025-01-24        NaN       NaN      NaN       NaN
# 2025-01-27        NaN       NaN      NaN       NaN
# 2025-01-28        NaN       NaN      NaN       NaN
# 2025-01-29        NaN       NaN      NaN       NaN
# 2025-01-30        NaN       NaN      NaN       NaN
#
# [2534 rows x 4 columns]

# %%
gp.analyze_volume_outliers(df_SPY)
# Out:
#             Volume SPY
# Date
# 2015-01-02         NaN
# 2015-01-05         NaN
# 2015-01-06         NaN
# 2015-01-07         NaN
# 2015-01-08         NaN
# ...                ...
# 2025-01-24         NaN
# 2025-01-27         NaN
# 2025-01-28         NaN
# 2025-01-29         NaN
# 2025-01-30         NaN
#
# [2535 rows x 1 columns]

# %%
gp.plot_rolling_mean(df_SPY)

# %%
gp.decompose_time_series(df_SPY, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 gp.decompose_time_series(df_SPY)
#
# TypeError: decompose_time_series() missing 1 required positional argument: 'asset'
